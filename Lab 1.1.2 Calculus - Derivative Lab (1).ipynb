# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Derivative

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function such as f(x) = x**3
def f(x):
  '''
  Return x**3
  '''
  return 0

# %%
# test the function you defined above by simply print its value for some numbers
print('f(2) = ',f(2))
print('f(5) = ',f(5))
print('f(-3) = ',f(-3))
# Out:
# f(2) =  0
# f(5) =  0
# f(-3) =  0

# %%
# plot f(x)
x = np.arange(-10,11,1)
y = f(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14488\2182028305.py in <module>
#       2 x = np.arange(-10,11,1)
#       3 y = f(x)
# ----> 4 plt.plot(x, y)
#       5 plt.xlabel('x')
#       6 plt.ylabel('f(x)')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %% [raw]
# NOTES
#
# ERROR MESSAGE ABOVE SOLVED BELOW . I HAVE RE WRIITEN THE WHOLE CODE FOR PRACTISE
#
# Error msg - ValueError: x and y must have same first dimension, but have shapes (21,) and (1,)
# This error is usually caused by an incorrect shape or size of the input data that is being passed to the plotting function. The most common scenario is that the two arrays or data sets have different lengths or shapes, and therefore cannot be plotted together.
#
# To fix this error, you should make sure that the two arrays you are trying to plot have the same length or shape. One way to check the shape of a NumPy array is to use the shape attribute. as shown below . but have shapes (21,) and (1,) so they do not have equal shapes thus causing error

# %%
print (x.shape)
# Out:
# (21,)

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function such as f(x) = x**3
def f(x):
  '''
  Return x**3
  '''
  return  x**3 # ERROR WAS HERE BECOZ OF RETURN 0

# %%
# test the function you defined above by simply print its value for some numbers
print('f(2) = ',f(2))
print('f(5) = ',f(5))
print('f(-3) = ',f(-3))
# Out:
# f(2) =  8
# f(5) =  125
# f(-3) =  -27

# %%
# plot f(x)
x = np.arange(-10,11,1)
y = f(x)
plt.plot(x, y, color='green')  #  plt.plot(x, y) - this is normal.  note  have changed colour  to green adding another function
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# BELOW CHECKING  that the two arrays  trying to plot have the same shape.

# %%
print (x.shape)
# Out:
# (21,)

# %%
print (y.shape)
# Out:
# (21,)

# %%
# define derivative function
def derivative(x):
    # set delta (change in x) to a small value, say 0.001
    delta = 1.0/1000.0
    # define rise (the change in f(x))
    rise = (f(x + delta)) - f(x)
    slope = rise / delta
    return slope

# %%
# test the derivative function for some values of x
print('derivative of f(2) = ', derivative(3))
print('derivative of f(-7) = ', derivative(-7))
# Out:
# derivative of f(2) =  27.009000999996147
# derivative of f(-7) =  146.9790010000338

# %%
# plot derivative of f(x)
x = np.arange(-10,11,1)
y = derivative(x)

# %%
# plot both x and derivative of f(x)
x = np.arange(-10,11,1)
y = f(x)

fig, ax1 = plt.subplots()

color = 'tab:green'
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)', color=color)
ax1.plot(x, y, color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.grid(which='major', axis='both', linestyle='--')

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

z = derivative(x)
color = 'tab:purple'
ax2.set_xlabel('x')
ax2.set_ylabel('derivative(x)', color=color)
ax2.plot(x, z, color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.grid(which='major', axis='both', linestyle='--')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
